# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
df = pd.read_csv("boston_house_prices.csv")
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  PRICE
# 0       15.3  396.90   4.98   24.0
# 1       17.8  396.90   9.14   21.6
# 2       17.8  392.83   4.03   34.7
# 3       18.7  394.63   2.94   33.4
# 4       18.7  396.90   5.33   36.2
# ..       ...     ...    ...    ...
# 501     21.0  391.99   9.67   22.4
# 502     21.0  396.90   9.08   20.6
# 503     21.0  396.90   5.64   23.9
# 504     21.0  393.45   6.48   22.0
# 505     21.0  396.90   7.88   11.9
#
# [506 rows x 14 columns]

# %%
x = df.drop("PRICE", axis=1)
y = df["PRICE"]

# %%
scaler = StandardScaler()
x = scaler.fit_transform(x)
x
# Out:
# array([[-0.41978194,  0.28482986, -1.2879095 , ..., -1.45900038,
#          0.44105193, -1.0755623 ],
#        [-0.41733926, -0.48772236, -0.59338101, ..., -0.30309415,
#          0.44105193, -0.49243937],
#        [-0.41734159, -0.48772236, -0.59338101, ..., -0.30309415,
#          0.39642699, -1.2087274 ],
#        ...,
#        [-0.41344658, -0.48772236,  0.11573841, ...,  1.17646583,
#          0.44105193, -0.98304761],
#        [-0.40776407, -0.48772236,  0.11573841, ...,  1.17646583,
#          0.4032249 , -0.86530163],
#        [-0.41500016, -0.48772236,  0.11573841, ...,  1.17646583,
#          0.44105193, -0.66905833]])

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state = 42)

# %%
model = Sequential()
model.add(Dense(128, activation ="relu"))
model.add(Dense(64, activation ="relu"))
model.add(Dense(32, activation ="relu"))
model.add(Dense(1, activation ="relu"))

model.compile(optimizer="adam", loss="mse", metrics=["mae"])

model.fit(x_train, y_train, epochs=25, batch_size = 32)
# Out:
# Epoch 1/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 572.9522 - mae: 22.0827
# Epoch 2/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 475.4316 - mae: 19.8074
# Epoch 3/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 289.5471 - mae: 14.7891
# Epoch 4/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 104.7446 - mae: 8.1499
# Epoch 5/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 61.1448 - mae: 6.0866
# Epoch 6/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 35.4624 - mae: 4.4111
# Epoch 7/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 28.3104 - mae: 3.8776
# Epoch 8/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 24.1418 - mae: 3.6201
# Epoch 9/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 21.4599 - mae: 3.3327
# Epoch 10/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.6218 - mae: 3.2495
# Epoch 11/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 17.9165 - mae: 3.0616
# Epoch 12/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 16.5854 - mae: 2.9407
# Epoch 13/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 15.6569 - mae: 2.8739
# Epoch 14/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 14.9208 - mae: 2.7753
# Epoch 15/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 14.3469 - mae: 2.7583
# Epoch 16/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 13.7698 - mae: 2.6671
# Epoch 17/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 13.3141 - mae: 2.6126
# Epoch 18/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 12.8732 - mae: 2.6069
# Epoch 19/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 12.4475 - mae: 2.5359
# Epoch 20/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 12.1565 - mae: 2.4851
# Epoch 21/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 11.9327 - mae: 2.4747
# Epoch 22/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 11.5695 - mae: 2.4535
# Epoch 23/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 11.4427 - mae: 2.4123
# Epoch 24/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.9671 - mae: 2.3870
# Epoch 25/25
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.8041 - mae: 2.3530

# %%
mse, mae = model.evaluate(x_train, y_train)
mae
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 10.4613 - mae: 2.3066
# 2.3065714836120605

# %%
mse, mae = model.evaluate(x_test, y_test)
mae
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 13.6899 - mae: 2.4672
# 2.4671850204467773
