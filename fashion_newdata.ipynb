# %% [markdown]
# <a href="https://colab.research.google.com/github/tanmaykulkarni2112/prac/blob/main/fashion_newdata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Flatten, Dense

# Read data
# Read corrupted CSV safely
df = pd.read_csv(
    "dataset.csv",
    engine="python",
    on_bad_lines="skip",
    encoding_errors="ignore"
)

# Remove missing rows
df = df.dropna()

# Text column
texts = df["review"].astype(str)

# Label column
labels = df["sentiment"].map({
    "positive": 1,
    "negative": 0
})

# Tokenize
tokenizer = Tokenizer(num_words=10000)

tokenizer.fit_on_texts(texts)

sequences = tokenizer.texts_to_sequences(texts)

# Pad
x = pad_sequences(sequences, maxlen=200)

# Convert labels
y = np.array(labels).astype("float32")

# Model
model = Sequential()

model.add(Embedding(input_dim=10000, output_dim=16, input_length=200))
model.add(Flatten())
model.add(Dense(16, activation="relu"))
model.add(Dense(1, activation="sigmoid"))

# Compile
model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

# Train
model.fit(x, y, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.6893 - loss: 0.5519
# Epoch 2/10
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9208 - loss: 0.2064
# Epoch 3/10
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9898 - loss: 0.0497
# Epoch 4/10
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9986 - loss: 0.0122
# Epoch 5/10
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 1.0000 - loss: 0.0039
# Epoch 6/10
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 1.0000 - loss: 0.0019
# Epoch 7/10
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 1.0000 - loss: 0.0011
# Epoch 8/10
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 1.0000 - loss: 7.4785e-04
# Epoch 9/10
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 1.0000 - loss: 5.3044e-04
# ...

# %%
loss, acc = model.evaluate(x,y)
acc
# Out:
# 321/321 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 3.1109e-04
# 1.0
